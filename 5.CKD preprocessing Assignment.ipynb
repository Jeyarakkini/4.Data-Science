# %%
import pandas as pd

# %%
dataset=pd.read_csv("kidney_disease.csv")
dataset
# Out:
#       id   age    bp     sg   al   su     rbc        pc         pcc  \
# 0      0  48.0  80.0  1.020  1.0  0.0     NaN    normal  notpresent
# 1      1   7.0  50.0  1.020  4.0  0.0     NaN    normal  notpresent
# 2      2  62.0  80.0  1.010  2.0  3.0  normal    normal  notpresent
# 3      3  48.0  70.0  1.005  4.0  0.0  normal  abnormal     present
# 4      4  51.0  80.0  1.010  2.0  0.0  normal    normal  notpresent
# ..   ...   ...   ...    ...  ...  ...     ...       ...         ...
# 395  395  55.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 396  396  42.0  70.0  1.025  0.0  0.0  normal    normal  notpresent
# 397  397  12.0  80.0  1.020  0.0  0.0  normal    normal  notpresent
# 398  398  17.0  60.0  1.025  0.0  0.0  normal    normal  notpresent
# 399  399  58.0  80.0  1.025  0.0  0.0  normal    normal  notpresent
#
#              ba  ...  pcv    wc   rc  htn   dm  cad appet   pe  ane  \
# 0    notpresent  ...   44  7800  5.2  yes  yes   no  good   no   no
# ...

# %%
dataset.isnull().sum()
# Out:
# id                  0
# age                 9
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
dataset["age"].fillna(dataset["age"].median(),inplace=True)

dataset.isnull().sum()
# Out:
# id                  0
# age                 0
# bp                 12
# sg                 47
# al                 46
# su                 49
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# bgr                44
# bu                 19
# sc                 17
# sod                87
# pot                88
# hemo               52
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
from Univariate import Univariate
quan,qual=Univariate.quanQual(dataset)
print(quan)
print(qual)
# Out:
# ['id', 'age', 'bp', 'sg', 'al', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot', 'hemo']
# ['rbc', 'pc', 'pcc', 'ba', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad', 'appet', 'pe', 'ane', 'classification']

# %%
dataset[quan]
# Out:
#       id   age    bp     sg   al   su    bgr    bu   sc    sod  pot  hemo
# 0      0  48.0  80.0  1.020  1.0  0.0  121.0  36.0  1.2    NaN  NaN  15.4
# 1      1   7.0  50.0  1.020  4.0  0.0    NaN  18.0  0.8    NaN  NaN  11.3
# 2      2  62.0  80.0  1.010  2.0  3.0  423.0  53.0  1.8    NaN  NaN   9.6
# 3      3  48.0  70.0  1.005  4.0  0.0  117.0  56.0  3.8  111.0  2.5  11.2
# 4      4  51.0  80.0  1.010  2.0  0.0  106.0  26.0  1.4    NaN  NaN  11.6
# ..   ...   ...   ...    ...  ...  ...    ...   ...  ...    ...  ...   ...
# 395  395  55.0  80.0  1.020  0.0  0.0  140.0  49.0  0.5  150.0  4.9  15.7
# 396  396  42.0  70.0  1.025  0.0  0.0   75.0  31.0  1.2  141.0  3.5  16.5
# 397  397  12.0  80.0  1.020  0.0  0.0  100.0  26.0  0.6  137.0  4.4  15.8
# 398  398  17.0  60.0  1.025  0.0  0.0  114.0  50.0  1.0  135.0  4.9  14.2
# 399  399  58.0  80.0  1.025  0.0  0.0  131.0  18.0  1.1  141.0  3.5  15.8
#
# [400 rows x 12 columns]

# %%
import numpy as np
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan, strategy='mean')
imp.fit(dataset[quan])
preQuan=imp.transform(dataset[quan])
preQuan = pd.DataFrame(preQuan,columns = quan)

# %%
preQuan
# Out:
#         id   age    bp     sg   al   su         bgr    bu   sc         sod  \
# 0      0.0  48.0  80.0  1.020  1.0  0.0  121.000000  36.0  1.2  137.528754
# 1      1.0   7.0  50.0  1.020  4.0  0.0  148.036517  18.0  0.8  137.528754
# 2      2.0  62.0  80.0  1.010  2.0  3.0  423.000000  53.0  1.8  137.528754
# 3      3.0  48.0  70.0  1.005  4.0  0.0  117.000000  56.0  3.8  111.000000
# 4      4.0  51.0  80.0  1.010  2.0  0.0  106.000000  26.0  1.4  137.528754
# ..     ...   ...   ...    ...  ...  ...         ...   ...  ...         ...
# 395  395.0  55.0  80.0  1.020  0.0  0.0  140.000000  49.0  0.5  150.000000
# 396  396.0  42.0  70.0  1.025  0.0  0.0   75.000000  31.0  1.2  141.000000
# 397  397.0  12.0  80.0  1.020  0.0  0.0  100.000000  26.0  0.6  137.000000
# 398  398.0  17.0  60.0  1.025  0.0  0.0  114.000000  50.0  1.0  135.000000
# 399  399.0  58.0  80.0  1.025  0.0  0.0  131.000000  18.0  1.1  141.000000
#
#           pot  hemo
# 0    4.627244  15.4
# 1    4.627244  11.3
# ...

# %%
preQuan.isnull().sum()
# Out:
# id      0
# age     0
# bp      0
# sg      0
# al      0
# su      0
# bgr     0
# bu      0
# sc      0
# sod     0
# pot     0
# hemo    0
# dtype: int64

# %%
dataset[qual]
# Out:
#         rbc        pc         pcc          ba pcv    wc   rc  htn   dm cad  \
# 0       NaN    normal  notpresent  notpresent  44  7800  5.2  yes  yes  no
# 1       NaN    normal  notpresent  notpresent  38  6000  NaN   no   no  no
# 2    normal    normal  notpresent  notpresent  31  7500  NaN   no  yes  no
# 3    normal  abnormal     present  notpresent  32  6700  3.9  yes   no  no
# 4    normal    normal  notpresent  notpresent  35  7300  4.6   no   no  no
# ..      ...       ...         ...         ...  ..   ...  ...  ...  ...  ..
# 395  normal    normal  notpresent  notpresent  47  6700  4.9   no   no  no
# 396  normal    normal  notpresent  notpresent  54  7800  6.2   no   no  no
# 397  normal    normal  notpresent  notpresent  49  6600  5.4   no   no  no
# 398  normal    normal  notpresent  notpresent  51  7200  5.9   no   no  no
# 399  normal    normal  notpresent  notpresent  53  6800  6.1   no   no  no
#
#     appet   pe  ane classification
# ...

# %%
dataset[qual].isnull().sum()
# Out:
# rbc               152
# pc                 65
# pcc                 4
# ba                  4
# pcv                70
# wc                105
# rc                130
# htn                 2
# dm                  2
# cad                 2
# appet               1
# pe                  1
# ane                 1
# classification      0
# dtype: int64

# %%
dataset['rbc'].fillna(dataset['rbc'].mode()[0],inplace=True)
dataset['pc'].fillna(dataset['pc'].mode()[0],inplace=True)
dataset['pcc'].fillna(dataset['pcc'].mode()[0],inplace=True)
dataset['ba'].fillna(dataset['ba'].mode()[0],inplace=True)
dataset['pcv'].fillna(dataset['pcv'].mode()[0],inplace=True)
dataset['wc'].fillna(dataset['wc'].mode()[0],inplace=True)
dataset['rc'].fillna(dataset['rc'].mode()[0],inplace=True)
dataset['htn'].fillna(dataset['htn'].mode()[0],inplace=True)
dataset['dm'].fillna(dataset['dm'].mode()[0],inplace=True)
dataset['cad'].fillna(dataset['cad'].mode()[0],inplace=True)
dataset['appet'].fillna(dataset['appet'].mode()[0],inplace=True)
dataset['pe'].fillna(dataset['pe'].mode()[0],inplace=True)
dataset['ane'].fillna(dataset['ane'].mode()[0],inplace=True)

# %%
dataset[qual]
# Out:
#         rbc        pc         pcc          ba pcv    wc   rc  htn   dm cad  \
# 0    normal    normal  notpresent  notpresent  44  7800  5.2  yes  yes  no
# 1    normal    normal  notpresent  notpresent  38  6000  5.2   no   no  no
# 2    normal    normal  notpresent  notpresent  31  7500  5.2   no  yes  no
# 3    normal  abnormal     present  notpresent  32  6700  3.9  yes   no  no
# 4    normal    normal  notpresent  notpresent  35  7300  4.6   no   no  no
# ..      ...       ...         ...         ...  ..   ...  ...  ...  ...  ..
# 395  normal    normal  notpresent  notpresent  47  6700  4.9   no   no  no
# 396  normal    normal  notpresent  notpresent  54  7800  6.2   no   no  no
# 397  normal    normal  notpresent  notpresent  49  6600  5.4   no   no  no
# 398  normal    normal  notpresent  notpresent  51  7200  5.9   no   no  no
# 399  normal    normal  notpresent  notpresent  53  6800  6.1   no   no  no
#
#     appet   pe  ane classification
# ...

# %%
dataset[qual].isnull().sum()
# Out:
# rbc               0
# pc                0
# pcc               0
# ba                0
# pcv               0
# wc                0
# rc                0
# htn               0
# dm                0
# cad               0
# appet             0
# pe                0
# ane               0
# classification    0
# dtype: int64

# %%
preQual=dataset[qual]
preQual
# Out:
#         rbc        pc         pcc          ba pcv    wc   rc  htn   dm cad  \
# 0    normal    normal  notpresent  notpresent  44  7800  5.2  yes  yes  no
# 1    normal    normal  notpresent  notpresent  38  6000  5.2   no   no  no
# 2    normal    normal  notpresent  notpresent  31  7500  5.2   no  yes  no
# 3    normal  abnormal     present  notpresent  32  6700  3.9  yes   no  no
# 4    normal    normal  notpresent  notpresent  35  7300  4.6   no   no  no
# ..      ...       ...         ...         ...  ..   ...  ...  ...  ...  ..
# 395  normal    normal  notpresent  notpresent  47  6700  4.9   no   no  no
# 396  normal    normal  notpresent  notpresent  54  7800  6.2   no   no  no
# 397  normal    normal  notpresent  notpresent  49  6600  5.4   no   no  no
# 398  normal    normal  notpresent  notpresent  51  7200  5.9   no   no  no
# 399  normal    normal  notpresent  notpresent  53  6800  6.1   no   no  no
#
#     appet   pe  ane classification
# ...

# %%
preQual.isnull().sum()
# Out:
# rbc               0
# pc                0
# pcc               0
# ba                0
# pcv               0
# wc                0
# rc                0
# htn               0
# dm                0
# cad               0
# appet             0
# pe                0
# ane               0
# classification    0
# dtype: int64

# %%
new=[preQuan,preQual]

# %%
dataset1=pd.concat(new,axis=1)

# %%
dataset1
# Out:
#         id   age    bp     sg   al   su         bgr    bu   sc         sod  \
# 0      0.0  48.0  80.0  1.020  1.0  0.0  121.000000  36.0  1.2  137.528754
# 1      1.0   7.0  50.0  1.020  4.0  0.0  148.036517  18.0  0.8  137.528754
# 2      2.0  62.0  80.0  1.010  2.0  3.0  423.000000  53.0  1.8  137.528754
# 3      3.0  48.0  70.0  1.005  4.0  0.0  117.000000  56.0  3.8  111.000000
# 4      4.0  51.0  80.0  1.010  2.0  0.0  106.000000  26.0  1.4  137.528754
# ..     ...   ...   ...    ...  ...  ...         ...   ...  ...         ...
# 395  395.0  55.0  80.0  1.020  0.0  0.0  140.000000  49.0  0.5  150.000000
# 396  396.0  42.0  70.0  1.025  0.0  0.0   75.000000  31.0  1.2  141.000000
# 397  397.0  12.0  80.0  1.020  0.0  0.0  100.000000  26.0  0.6  137.000000
# 398  398.0  17.0  60.0  1.025  0.0  0.0  114.000000  50.0  1.0  135.000000
# 399  399.0  58.0  80.0  1.025  0.0  0.0  131.000000  18.0  1.1  141.000000
#
# ...

# %%
import numpy as np

# %%
quan,qual=Univariate.quanQual(dataset1)

# %%
descriptive=Univariate.descriptive(dataset1,quan)
descriptive
# Out:
#                   id      age       bp       sg       al        su      bgr  \
# Max              399       90      180    1.025        5         5      490
# Min                0        2       50    1.005        0         0       22
# Mean           199.5  51.5625  76.4691  1.01741  1.01695  0.450142  148.037
# Median         199.5       55  78.2345  1.01741        1         0      126
# Mode               0       55       80     1.02        0         0  148.037
# Q1:25%         99.75       42       70    1.015        0         0      101
# Q2:50%         199.5       55  78.2345  1.01741        1         0      126
# Q3:75%        299.25       64       80     1.02        2  0.450142      150
# Q4:100%          399       90      180    1.025        5         5      490
# IQR            199.5       22       10    0.005        2  0.450142       49
# 1.5IQR        299.25       33       15   0.0075        3  0.675214     73.5
# ...

# %%
lesser,greater=Univariate.findOutlier(descriptive,quan)

# %%
lesser
# Out:
# ['age', 'bp', 'sg', 'bgr', 'sod', 'pot', 'hemo']

# %%
greater
# Out:
# ['bp', 'su', 'bgr', 'bu', 'sc', 'sod', 'pot']

# %%
dataset2=Univariate.replaceOutlier(dataset1,descriptive,lesser,greater,quan)
# Out:
# D:\HopeAI\5.Data Science - Univariate\Univariate Assignment\Univariate.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset[columnName][dataset[columnName]<descriptive[columnName]['lesserRange']]=descriptive[columnName]['lesserRange']
# D:\HopeAI\5.Data Science - Univariate\Univariate Assignment\Univariate.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset[columnName][dataset[columnName]>descriptive[columnName]['greaterRange']]=descriptive[columnName]['greaterRange']

# %%
dataset2
# Out:
#         id   age    bp      sg   al        su         bgr    bu   sc  \
# 0      0.0  48.0  80.0  1.0200  1.0  0.000000  121.000000  36.0  1.2
# 1      1.0   9.0  55.0  1.0200  4.0  0.000000  148.036517  18.0  0.8
# 2      2.0  62.0  80.0  1.0100  2.0  1.125356  223.500000  53.0  1.8
# 3      3.0  48.0  70.0  1.0075  4.0  0.000000  117.000000  56.0  3.8
# 4      4.0  51.0  80.0  1.0100  2.0  0.000000  106.000000  26.0  1.4
# ..     ...   ...   ...     ...  ...       ...         ...   ...  ...
# 395  395.0  55.0  80.0  1.0200  0.0  0.000000  140.000000  49.0  0.5
# 396  396.0  42.0  70.0  1.0250  0.0  0.000000   75.000000  31.0  1.2
# 397  397.0  12.0  80.0  1.0200  0.0  0.000000  100.000000  26.0  0.6
# 398  398.0  17.0  60.0  1.0250  0.0  0.000000  114.000000  50.0  1.0
# 399  399.0  58.0  80.0  1.0250  0.0  0.000000  131.000000  18.0  1.1
#
#             sod  ...  pcv    wc   rc  htn   dm cad appet   pe  ane  \
# 0    137.528754  ...   44  7800  5.2  yes  yes  no  good   no   no
# ...

# %%
quan,qual=Univariate.quanQual(dataset2)
descriptive=Univariate.descriptive(dataset2,quan)
descriptive
# Out:
#                   id      age       bp       sg       al        su      bgr  \
# Max              399       90       95    1.025        5   1.12536    223.5
# Min                0        9       55   1.0075        0         0     27.5
# Mean           199.5  51.6475  75.7191  1.01745  1.01695  0.222685  136.985
# Median         199.5       55  78.2345  1.01741        1         0      126
# Mode               0       55       80     1.02        0         0    223.5
# Q1:25%         99.75       42       70    1.015        0         0      101
# Q2:50%         199.5       55  78.2345  1.01741        1         0      126
# Q3:75%        299.25       64       80     1.02        2  0.450142      150
# Q4:100%          399       90       95    1.025        5   1.12536    223.5
# IQR            199.5       22       10    0.005        2  0.450142       49
# 1.5IQR        299.25       33       15   0.0075        3  0.675214     73.5
# ...

# %%
lesser,greater=Univariate.findOutlier(descriptive,quan)

# %%
lesser
# Out:
# []

# %%
greater
# Out:
# []

# %%
dataset2.to_csv('preprocessedCKD.csv', index=False)
