# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
dataset=pd.read_csv("Placement_Data_Full_Class.csv")
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1.0      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2.0      M  79.33  Central  78.33   Others   Science     77.48
# 2      3.0      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4.0      M  56.00  Central  52.00  Central   Science     52.00
# 4      5.0      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 212  211.0      M  80.60   Others  82.00   Others  Commerce     77.60
# 213  212.0      M  58.00   Others  60.00   Others   Science     72.00
# 214  213.0      M  67.00   Others  67.00   Others  Commerce     73.00
# 215  214.0      F  74.00   Others  66.00   Others  Commerce     58.00
# 216  215.0      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dir(dataset)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
# ...

# %%
dataset.isnull().sum()
# Out:
# sl_no              2
# gender             2
# ssc_p              2
# ssc_b              2
# hsc_p              2
# hsc_b              2
# hsc_s              2
# degree_p           2
# degree_t           2
# workex             2
# etest_p            2
# specialisation     2
# mba_p              2
# status             2
# salary            69
# dtype: int64

# %%
dataset.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0    1.0      M  67.00   Others  91.00   Others  Commerce     58.00
# 1    2.0      M  79.33  Central  78.33   Others   Science     77.48
# 2    3.0      M  65.00  Central  68.00  Central      Arts     64.00
# 3    4.0      M  56.00  Central  52.00  Central   Science     52.00
# 4    5.0      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
pd.set_option('display.max_rows', None)

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1.0      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2.0      M  79.33  Central  78.33   Others   Science     77.48
# 2      3.0      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4.0      M  56.00  Central  52.00  Central   Science     52.00
# 4      5.0      M  85.80  Central  73.60  Central  Commerce     73.30
# 5      6.0      M  55.00   Others  49.80   Others   Science     67.25
# 6      7.0      F  46.00   Others  49.20   Others  Commerce     79.00
# 7      NaN    NaN    NaN      NaN    NaN      NaN       NaN       NaN
# 8      NaN    NaN    NaN      NaN    NaN      NaN       NaN       NaN
# 9      8.0      M  82.00  Central  64.00  Central   Science     66.00
# 10     9.0      M  73.00  Central  79.00  Central  Commerce     72.00
# 11    10.0      M  58.00  Central  70.00  Central  Commerce     61.00
# ...

# %%
dataset.drop([7,8],inplace=True)

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1.0      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2.0      M  79.33  Central  78.33   Others   Science     77.48
# 2      3.0      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4.0      M  56.00  Central  52.00  Central   Science     52.00
# 4      5.0      M  85.80  Central  73.60  Central  Commerce     73.30
# 5      6.0      M  55.00   Others  49.80   Others   Science     67.25
# 6      7.0      F  46.00   Others  49.20   Others  Commerce     79.00
# 9      8.0      M  82.00  Central  64.00  Central   Science     66.00
# 10     9.0      M  73.00  Central  79.00  Central  Commerce     72.00
# 11    10.0      M  58.00  Central  70.00  Central  Commerce     61.00
# 12    11.0      M  58.00  Central  61.00  Central  Commerce     60.00
# 13    12.0      M  69.60  Central  68.40  Central  Commerce     78.30
# ...

# %%
dataset["salary"].min()
# Out:
# 200000.0

# %%
dataset[dataset["salary"] == 200000]
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 1      2.0      M  79.33  Central  78.33   Others   Science     77.48
# 17    16.0      F  65.00  Central  75.00  Central  Commerce     69.00
# 46    45.0      F  77.00   Others  73.00   Others  Commerce     81.00
# 52    51.0      F  75.20  Central  73.20  Central   Science     68.40
# 109  108.0      M  82.00   Others  90.00   Others  Commerce     83.00
# 137  136.0      F  72.00  Central  56.00   Others   Science     69.00
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# 1     Sci&Tech    Yes     86.5        Mkt&Fin  66.28  Placed  200000.0
# 17   Comm&Mgmt    Yes     72.0        Mkt&Fin  64.66  Placed  200000.0
# 46   Comm&Mgmt    Yes     89.0        Mkt&Fin  69.70  Placed  200000.0
# 52   Comm&Mgmt     No     65.0         Mkt&HR  62.98  Placed  200000.0
# 109  Comm&Mgmt     No     80.0         Mkt&HR  73.52  Placed  200000.0
# ...

# %%
dataset["salary"].fillna(0,inplace=True)

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1.0      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2.0      M  79.33  Central  78.33   Others   Science     77.48
# 2      3.0      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4.0      M  56.00  Central  52.00  Central   Science     52.00
# 4      5.0      M  85.80  Central  73.60  Central  Commerce     73.30
# 5      6.0      M  55.00   Others  49.80   Others   Science     67.25
# 6      7.0      F  46.00   Others  49.20   Others  Commerce     79.00
# 9      8.0      M  82.00  Central  64.00  Central   Science     66.00
# 10     9.0      M  73.00  Central  79.00  Central  Commerce     72.00
# 11    10.0      M  58.00  Central  70.00  Central  Commerce     61.00
# 12    11.0      M  58.00  Central  61.00  Central  Commerce     60.00
# 13    12.0      M  69.60  Central  68.40  Central  Commerce     78.30
# ...

# %%
dataset.isnull().sum()
# Out:
# sl_no             0
# gender            0
# ssc_p             0
# ssc_b             0
# hsc_p             0
# hsc_b             0
# hsc_s             0
# degree_p          0
# degree_t          0
# workex            0
# etest_p           0
# specialisation    0
# mba_p             0
# status            0
# salary            0
# dtype: int64

# %%
dataset['status'][dataset["status"]=="Not Placed"].count()
# Out:
# 67

# %%
dataset.groupby("status")[["specialisation"]]

# %%
dataset.groupby("status")[["ssc_p", "hsc_p", "degree_p", "mba_p"]].mean()
# Out:
#                 ssc_p      hsc_p   degree_p      mba_p
# status
# Not Placed  57.544030  58.395522  61.134179  61.612836
# Placed      71.721486  69.926554  68.740541  62.579392

# %%
#sns.countplot(x='specialisation',hue='status',palette='seismic', data=dataset)
#sns.boxplot(x="status", y="ssc_p", data=dataset)

# %%
sns.barplot(x="specialisation",y='salary', hue="workex",palette='rainbow', data=dataset)

# %%
dataset[dataset['salary'] > 500000]
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 121  120.0      M   60.8  Central  68.40  Central  Commerce      64.6
# 152  151.0      M   71.0  Central  58.66  Central   Science      58.0
# 179  178.0      F   73.0  Central  97.00   Others  Commerce      79.0
#
#       degree_t workex  etest_p specialisation  mba_p  status    salary
# 121  Comm&Mgmt    Yes    82.66        Mkt&Fin  64.34  Placed  940000.0
# 152   Sci&Tech    Yes    56.00        Mkt&Fin  61.30  Placed  690000.0
# 179  Comm&Mgmt    Yes    89.00        Mkt&Fin  70.81  Placed  650000.0

# %%
dataset['salary'][dataset['salary'] > 500000].count()
# Out:
# 3

# %%
from Univariate import Univariate

# %%
quan,qual=Univariate.quanQual(dataset)
print(quan)
print(qual)
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']
# ['gender', 'ssc_b', 'hsc_b', 'hsc_s', 'degree_t', 'workex', 'specialisation', 'status']

# %%
descriptive=Univariate.descriptive(dataset,quan)
descriptive
# Out:
#               sl_no    ssc_p    hsc_p degree_p  etest_p    mba_p  salary
# Max             215     89.4     97.7       91       98    77.89  940000
# Min               1    40.89       37       50       50    51.21       0
# Mean            108  67.3034  66.3332  66.3702  72.1006  62.2782  198702
# Median          108       67       65       66       71       62  240000
# Mode              1       62       63       65       60     56.7       0
# Q1:25%         54.5     60.6     60.9       61       60   57.945       0
# Q2:50%          108       67       65       66       71       62  240000
# Q3:75%        161.5     75.7       73       72     83.5   66.255  282500
# Q4:100%         215     89.4     97.7       91       98    77.89  940000
# IQR             107     15.1     12.1       11     23.5     8.31  282500
# 1.5IQR        160.5    22.65    18.15     16.5    35.25   12.465  423750
# lesserRange    -106    37.95    42.75     44.5    24.75    45.48 -423750
# ...

# %%
dataset.cov()
# Out:
#                  sl_no          ssc_p          hsc_p       degree_p  \
# sl_no      3870.000000     -52.641355     -58.106028     -40.413645
# ssc_p       -52.641355     117.228377      60.348373      42.897137
# hsc_p       -58.106028      60.348373     118.755706      34.819820
# degree_p    -40.413645      42.897137      34.819820      54.151103
# etest_p      52.556168      37.659225      35.461678      21.929469
# mba_p         8.102336      24.535952      22.555846      17.272020
# salary    24490.654206  901754.893936  763359.777657  465131.504238
#
#                 etest_p          mba_p        salary
# sl_no         52.556168       8.102336  2.449065e+04
# ssc_p         37.659225      24.535952  9.017549e+05
# hsc_p         35.461678      22.555846  7.633598e+05
# degree_p      21.929469      17.272020  4.651315e+05
# etest_p      176.251018      16.886973  3.842344e+05
# mba_p         16.886973      34.028376  1.262455e+05
# ...

# %% [markdown]
# ### Positive relation between mba_p and salary

# %%
dataset.corr()
# Out:
#              sl_no     ssc_p     hsc_p  degree_p   etest_p     mba_p    salary
# sl_no     1.000000 -0.078155 -0.085711 -0.088281  0.063636  0.022327  0.002543
# ssc_p    -0.078155  1.000000  0.511472  0.538404  0.261993  0.388478  0.538090
# hsc_p    -0.085711  0.511472  1.000000  0.434206  0.245113  0.354823  0.452569
# degree_p -0.088281  0.538404  0.434206  1.000000  0.224470  0.402364  0.408371
# etest_p   0.063636  0.261993  0.245113  0.224470  1.000000  0.218055  0.186988
# mba_p     0.022327  0.388478  0.354823  0.402364  0.218055  1.000000  0.139823
# salary    0.002543  0.538090  0.452569  0.408371  0.186988  0.139823  1.000000

# %% [markdown]
# #### Not strongly related as correlation is 0.13

# %%
import seaborn as sns

# %%
non_zero_salaries = dataset['salary'][dataset['salary'] > 0]

# %%
sns.distplot(non_zero_salaries)
# Out:
# C:\Anaconda3\envs\aiml\lib\site-packages\ipykernel_launcher.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# The graph is bimodal indicating that Salary is not normlly distributed

# %%
def get_pdf_probability(dataset,startrange,endrange):                                                              #giving the inputs dataset,start range,end range as parameters.
    from matplotlib import pyplot                                                                                    # importing matplotlib for plotting graph
    from scipy.stats import norm                                                                            # importing spicy.stats for using normal distribution
    import seaborn as sns                                                                                    # importing seaborn for giving colors to the graph
    ax = sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')                         # distplot is used to see the distribution
    pyplot.axvline(startrange,color='Red')                                                                         # axv line is the vertical line. used here to denote the starting range
    pyplot.axvline(endrange,color='Red')                                                          # axv line is the vertical line. used here to denote the end range
    # generate a sample
    sample = dataset
    # calculate parameters
    sample_mean =sample.mean()                                                                            # calculating mean and std dev
    sample_std = sample.std()
    print('Mean=%.3f, Standard Deviation=%.3f' % (sample_mean, sample_std))                               # printing mean and std dev with 3 decimal values
    # define the distribution
    dist = norm(sample_mean, sample_std)  # computes the norm
    
    # sample probabilities for a range of outcomes
    values = [value for value in range(startrange, endrange)]                                         # one liner for 'for' loop . it creates 'value' as list.
    probabilities = [dist.pdf(value) for value in values]                                              # calculating the probability values and plotting distribution plot.
    prob=sum(probabilities)                                                                                     # adding the probability values
    print("The area between range({},{}):{}".format(startrange,endrange,sum(probabilities)))                   #printing area which is the sum of probabilities
    return prob

# %%
get_pdf_probability(non_zero_salaries,700000,900000)
# Out:
# C:\Anaconda3\envs\aiml\lib\site-packages\ipykernel_launcher.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """
# Mean=288655.405, Standard Deviation=93457.452
# The area between range(700000,900000):5.377578376230696e-06
# 5.377578376230696e-06

# %%
def stdNBgraph(dataset):
       
    import seaborn as sns
    mean=dataset.mean() 
    std=dataset.std()   

    values=[i for i in dataset] 

    z_score=[((j-mean)/std) for j in values]
    sns.distplot(z_score,kde=True)   

    sum(z_score)/len(z_score)

# %%
stdNBgraph(non_zero_salaries)
# Out:
# C:\Anaconda3\envs\aiml\lib\site-packages\ipykernel_launcher.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# from scipy.stats import ttest_ind
# dataset=dataset.dropna()
# male = dataset[dataset['gender']=='M']['salary']
# female = dataset[dataset['gender']=='F']['salary']
# #print(male)
# ttest_ind(male, female)

# %%
from scipy.stats import ttest_rel
#dataset=dataset.dropna()
male = dataset[dataset['gender']=='M']['ssc_p']
male1 = dataset[dataset['gender']=='M']['hsc_p']
ttest_rel(male, male1)
# Out:
# Ttest_relResult(statistic=0.6852881050898078, pvalue=0.49431164600731503)

# %% [markdown]
# T-Test to find if there is a difference in   etest_p and mba_p of degree_t(Sci&Tech).

# %%
from scipy.stats import ttest_rel
etest=dataset['etest_p'][dataset['degree_t'] == 'Sci&Tech' ]
mba=dataset['mba_p'][dataset['degree_t'] == 'Sci&Tech' ]
ttest_rel(etest, mba)
# Out:
# Ttest_relResult(statistic=5.0049844583693615, pvalue=5.517920600505392e-06)

# %% [markdown]
# p > 0.05 . Accept null hypothesis.
# There is a significant difference between the mean of etest_p and mba_p of sci&Tech students

# %% [markdown]
# Testing if theres a diff in the salary of degree_t(Sci&Tech) students and specialisation(Mkt&HR) students
# salary of specialisation(Mkt&HR) students and specialisation(Mkt&Fin)

# %%
from scipy.stats import ttest_ind
sci = dataset['salary'][dataset['degree_t'] == 'Sci&Tech']
hr = dataset['salary'][dataset['specialisation'] == 'Mkt&HR']
ttest_ind(sci,hr)
# Out:
# Ttest_indResult(statistic=2.692041243555374, pvalue=0.007897969943471179)

# %% [markdown]
# p < 0.05. Reject null hypothesis.
# There is a significant difference in the salary of degree_t(Sci&Tech) students and specialisation(Mkt&HR) students

# %%
#salary of specialisation(Mkt&HR) students and specialisation(Mkt&Fin)

# %% [markdown]
# Analysis of Variance between etest_p and mba_p at signifance level 5%

# %%
import scipy.stats as stats

stats.f_oneway(dataset['etest_p'],dataset['mba_p'])
# Out:
# F_onewayResult(statistic=98.64487057324706, pvalue=4.672547689133573e-21)

# %% [markdown]
# p > 0.05. There is a significant difference between the two columns.

# %%
sns.barplot(x="degree_t",y='salary', hue="specialisation",palette='rainbow', data=dataset)

# %%
sns.barplot(x="specialisation",y='mba_p', hue="status",palette='rainbow', data=dataset)

# %%
sns.barplot(x="specialisation",y='ssc_p', hue="status",palette='rainbow', data=dataset)

# %%
sns.barplot(x="specialisation",y='hsc_p', hue="status",palette='rainbow', data=dataset)

# %%
sns.distplot(dataset['mba_p'])
sns.kdeplot(dataset['ssc_p'])
# Out:
# C:\Anaconda3\envs\aiml\lib\site-packages\ipykernel_launcher.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """Entry point for launching an IPython kernel.

# %%
sns.catplot(x="workex",y='mba_p', hue="status",palette='rainbow', data=dataset)

# %%
sns.catplot(x="workex",y='ssc_p', hue="status",palette='rainbow', data=dataset)
